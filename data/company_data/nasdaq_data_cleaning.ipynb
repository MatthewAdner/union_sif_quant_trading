# %%
import pandas as pd
import yfinance as yf
import numpy as np
import re
# files from https://www.nasdaq.com/market-activity/stocks/screener
# files gotten on 2024-09-29

date = '2024-09-29'

# %%
nasdaq = pd.read_csv('nasdaq_screener_nasdaq_'+date+'.csv')
nyse = pd.read_csv('nasdaq_screener_nyse_'+date+'.csv')
nyse['Exchange'] = 'NYSE'
nasdaq['Exchange'] = 'NASDAQ'
company_data = pd.concat([nyse,nasdaq],axis=0)
del(nyse,nasdaq)
company_data = company_data.rename(columns={'Symbol':'Ticker'})
# company_data.index=company_data['Symbol']
# nyse_and_nasdaq.drop(columns='Symbol',inplace=True)
# nyse_and_nasdaq.index.name='Ticker'
company_data
# Out:
#      Ticker                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $148.06
# 1        AA                    Alcoa Corporation Common Stock     $39.27
# 2      AACT  Ares Acquisition Corporation II Class A Ordina...  $10.8299
# 3       AAM  AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# 4       AAN         Aarons Holdings Company Inc. Common Stock     $10.05
# ...     ...                                                ...       ...
# 3905   ZURA           Zura Bio Limited Class A Ordinary Shares     $4.07
# 3906   ZVRA               Zevra Therapeutics Inc. Common Stock     $6.92
# 3907   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $2.36
# 3908   ZYME                        Zymeworks Inc. Common Stock    $12.42
# 3909   ZYXI                            Zynex Inc. Common Stock     $8.10
#
#       Net Change % Change    Market Cap         Country  IPO Year   Volume  \
# 0         1.3200    0.90%  4.254173e+10   United States    1999.0  2212993
# 1        -0.0100  -0.025%  1.014502e+10   United States    2016.0  5629158
# 2         0.0199   0.184%  0.000000e+00             NaN    2023.0     2476
# 3         0.0000    0.00%  0.000000e+00             NaN    2024.0   537105
# 4         0.0200   0.199%  3.086634e+08   United States    2020.0  1425538
# ...          ...      ...           ...             ...       ...      ...
# 3905      0.1000   2.519%  2.735328e+08  Cayman Islands       NaN   393346
# 3906     -0.3900  -5.335%  3.641151e+08   United States       NaN  1660748
# 3907      0.0600   2.609%  2.428903e+06   United States    2022.0    53919
# 3908     -0.0500  -0.401%  8.824086e+08   United States       NaN   283590
# 3909     -0.1600  -1.937%  2.571144e+08   United States       NaN   105359
#
#                       Sector  \
# 0                Industrials
# 1                Industrials
# 2                    Finance
# 3                        NaN
# 4     Consumer Discretionary
# ...                      ...
# 3905             Health Care
# 3906             Health Care
# 3907             Health Care
# 3908             Health Care
# 3909             Health Care
#
#                                                Industry Exchange
# 0      Biotechnology: Laboratory Analytical Instruments     NYSE
# 1                                              Aluminum     NYSE
# 2                                          Blank Checks     NYSE
# 3                                                   NaN     NYSE
# 4                       Diversified Commercial Services     NYSE
# ...                                                 ...      ...
# 3905  Biotechnology: Biological Products (No Diagnos...   NASDAQ
# 3906         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3907         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3908         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3909  Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6690 rows x 12 columns]

# %%
odd = list({x for x in company_data['Ticker'] if (not (str(x).isalnum()))})
odd_with_arrow = list({x for x in company_data['Ticker'] if  (str(x).__contains__('^')) })
odd_no_arrow = list({x for x in company_data['Ticker'] if (not (str(x).isalnum()) and  not (str(x).__contains__('^')) )})
company_data
# Out:
#      Ticker                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $148.06
# 1        AA                    Alcoa Corporation Common Stock     $39.27
# 2      AACT  Ares Acquisition Corporation II Class A Ordina...  $10.8299
# 3       AAM  AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# 4       AAN         Aarons Holdings Company Inc. Common Stock     $10.05
# ...     ...                                                ...       ...
# 3905   ZURA           Zura Bio Limited Class A Ordinary Shares     $4.07
# 3906   ZVRA               Zevra Therapeutics Inc. Common Stock     $6.92
# 3907   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $2.36
# 3908   ZYME                        Zymeworks Inc. Common Stock    $12.42
# 3909   ZYXI                            Zynex Inc. Common Stock     $8.10
#
#       Net Change % Change    Market Cap         Country  IPO Year   Volume  \
# 0         1.3200    0.90%  4.254173e+10   United States    1999.0  2212993
# 1        -0.0100  -0.025%  1.014502e+10   United States    2016.0  5629158
# 2         0.0199   0.184%  0.000000e+00             NaN    2023.0     2476
# 3         0.0000    0.00%  0.000000e+00             NaN    2024.0   537105
# 4         0.0200   0.199%  3.086634e+08   United States    2020.0  1425538
# ...          ...      ...           ...             ...       ...      ...
# 3905      0.1000   2.519%  2.735328e+08  Cayman Islands       NaN   393346
# 3906     -0.3900  -5.335%  3.641151e+08   United States       NaN  1660748
# 3907      0.0600   2.609%  2.428903e+06   United States    2022.0    53919
# 3908     -0.0500  -0.401%  8.824086e+08   United States       NaN   283590
# 3909     -0.1600  -1.937%  2.571144e+08   United States       NaN   105359
#
#                       Sector  \
# 0                Industrials
# 1                Industrials
# 2                    Finance
# 3                        NaN
# 4     Consumer Discretionary
# ...                      ...
# 3905             Health Care
# 3906             Health Care
# 3907             Health Care
# 3908             Health Care
# 3909             Health Care
#
#                                                Industry Exchange
# 0      Biotechnology: Laboratory Analytical Instruments     NYSE
# 1                                              Aluminum     NYSE
# 2                                          Blank Checks     NYSE
# 3                                                   NaN     NYSE
# 4                       Diversified Commercial Services     NYSE
# ...                                                 ...      ...
# 3905  Biotechnology: Biological Products (No Diagnos...   NASDAQ
# 3906         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3907         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3908         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 3909  Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6690 rows x 12 columns]

# %%
# there seem to be a few types of odd tickers here, ones formatted like xxx^x and ones with xx/x in it and/or whitespace.
# it seems like all the rows with a ticker of the format "xxx^x" are something like prefered stock or some other nonsense
# the ones with / need to have the / swapped with - for the yfinance library to get their data
# and the whitespace needs to be removed. This does that
odd_cleaned = {x: re.split('[^a-zA-Z0-9]+', x)[0] for x in odd_with_arrow}
odd_cleaned.update({x: x.strip().replace('/', '-') for x in odd_no_arrow})
# and this updates the names in the dataframe
company_data['Ticker'] = company_data['Ticker'].replace(odd_cleaned)
company_data = company_data.reset_index()
company_data = company_data.drop(columns='index')
company_data
# Out:
#      Ticker                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $148.06
# 1        AA                    Alcoa Corporation Common Stock     $39.27
# 2      AACT  Ares Acquisition Corporation II Class A Ordina...  $10.8299
# 3       AAM  AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# 4       AAN         Aarons Holdings Company Inc. Common Stock     $10.05
# ...     ...                                                ...       ...
# 6685   ZURA           Zura Bio Limited Class A Ordinary Shares     $4.07
# 6686   ZVRA               Zevra Therapeutics Inc. Common Stock     $6.92
# 6687   ZVSA             ZyVersa Therapeutics Inc. Common Stock     $2.36
# 6688   ZYME                        Zymeworks Inc. Common Stock    $12.42
# 6689   ZYXI                            Zynex Inc. Common Stock     $8.10
#
#       Net Change % Change    Market Cap         Country  IPO Year   Volume  \
# 0         1.3200    0.90%  4.254173e+10   United States    1999.0  2212993
# 1        -0.0100  -0.025%  1.014502e+10   United States    2016.0  5629158
# 2         0.0199   0.184%  0.000000e+00             NaN    2023.0     2476
# 3         0.0000    0.00%  0.000000e+00             NaN    2024.0   537105
# 4         0.0200   0.199%  3.086634e+08   United States    2020.0  1425538
# ...          ...      ...           ...             ...       ...      ...
# 6685      0.1000   2.519%  2.735328e+08  Cayman Islands       NaN   393346
# 6686     -0.3900  -5.335%  3.641151e+08   United States       NaN  1660748
# 6687      0.0600   2.609%  2.428903e+06   United States    2022.0    53919
# 6688     -0.0500  -0.401%  8.824086e+08   United States       NaN   283590
# 6689     -0.1600  -1.937%  2.571144e+08   United States       NaN   105359
#
#                       Sector  \
# 0                Industrials
# 1                Industrials
# 2                    Finance
# 3                        NaN
# 4     Consumer Discretionary
# ...                      ...
# 6685             Health Care
# 6686             Health Care
# 6687             Health Care
# 6688             Health Care
# 6689             Health Care
#
#                                                Industry Exchange
# 0      Biotechnology: Laboratory Analytical Instruments     NYSE
# 1                                              Aluminum     NYSE
# 2                                          Blank Checks     NYSE
# 3                                                   NaN     NYSE
# 4                       Diversified Commercial Services     NYSE
# ...                                                 ...      ...
# 6685  Biotechnology: Biological Products (No Diagnos...   NASDAQ
# 6686         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 6687         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 6688         Biotechnology: Pharmaceutical Preparations   NASDAQ
# 6689  Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6690 rows x 12 columns]

# %%
# 
company_data.index = company_data['Ticker']
company_data = company_data.drop(columns=['Ticker'])
# clean up invalid data
company_data = company_data[company_data.index.notna()]

# %%
company_data
# Out:
#                                                      Name Last Sale  \
# Ticker
# A                  Agilent Technologies Inc. Common Stock   $148.06
# AA                        Alcoa Corporation Common Stock     $39.27
# AACT    Ares Acquisition Corporation II Class A Ordina...  $10.8299
# AAM     AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# AAN            Aarons Holdings Company Inc. Common Stock     $10.05
# ...                                                   ...       ...
# ZURA             Zura Bio Limited Class A Ordinary Shares     $4.07
# ZVRA                 Zevra Therapeutics Inc. Common Stock     $6.92
# ZVSA               ZyVersa Therapeutics Inc. Common Stock     $2.36
# ZYME                          Zymeworks Inc. Common Stock    $12.42
# ZYXI                              Zynex Inc. Common Stock     $8.10
#
#         Net Change % Change    Market Cap         Country  IPO Year   Volume  \
# Ticker
# A           1.3200    0.90%  4.254173e+10   United States    1999.0  2212993
# AA         -0.0100  -0.025%  1.014502e+10   United States    2016.0  5629158
# AACT        0.0199   0.184%  0.000000e+00             NaN    2023.0     2476
# AAM         0.0000    0.00%  0.000000e+00             NaN    2024.0   537105
# AAN         0.0200   0.199%  3.086634e+08   United States    2020.0  1425538
# ...            ...      ...           ...             ...       ...      ...
# ZURA        0.1000   2.519%  2.735328e+08  Cayman Islands       NaN   393346
# ZVRA       -0.3900  -5.335%  3.641151e+08   United States       NaN  1660748
# ZVSA        0.0600   2.609%  2.428903e+06   United States    2022.0    53919
# ZYME       -0.0500  -0.401%  8.824086e+08   United States       NaN   283590
# ZYXI       -0.1600  -1.937%  2.571144e+08   United States       NaN   105359
#
#                         Sector  \
# Ticker
# A                  Industrials
# AA                 Industrials
# AACT                   Finance
# AAM                        NaN
# AAN     Consumer Discretionary
# ...                        ...
# ZURA               Health Care
# ZVRA               Health Care
# ZVSA               Health Care
# ZYME               Health Care
# ZYXI               Health Care
#
#                                                  Industry Exchange
# Ticker
# A        Biotechnology: Laboratory Analytical Instruments     NYSE
# AA                                               Aluminum     NYSE
# AACT                                         Blank Checks     NYSE
# AAM                                                   NaN     NYSE
# AAN                       Diversified Commercial Services     NYSE
# ...                                                   ...      ...
# ZURA    Biotechnology: Biological Products (No Diagnos...   NASDAQ
# ZVRA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZVSA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYME           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYXI    Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6689 rows x 11 columns]

# %%
# Rename columns to be more code friendly (underscores)
rename_dict = {
    'Name': 'Name',
    'Last Sale': 'Last_Sale',
    'Net Change': 'Net_Change',
    '% Change': 'Percent_Change',
    'Market Cap': 'Market_Cap',
    'Country': 'Country',
    'IPO Year': 'IPO_Year',
    'Volume': 'Volume',
    'Sector': 'Sector',
    'Industry': 'Industry',
    'Exchange': 'Exchange'
}
company_data = company_data.rename(columns=rename_dict)
company_data
# Out:
#                                                      Name Last_Sale  \
# Ticker
# A                  Agilent Technologies Inc. Common Stock   $148.06
# AA                        Alcoa Corporation Common Stock     $39.27
# AACT    Ares Acquisition Corporation II Class A Ordina...  $10.8299
# AAM     AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# AAN            Aarons Holdings Company Inc. Common Stock     $10.05
# ...                                                   ...       ...
# ZURA             Zura Bio Limited Class A Ordinary Shares     $4.07
# ZVRA                 Zevra Therapeutics Inc. Common Stock     $6.92
# ZVSA               ZyVersa Therapeutics Inc. Common Stock     $2.36
# ZYME                          Zymeworks Inc. Common Stock    $12.42
# ZYXI                              Zynex Inc. Common Stock     $8.10
#
#         Net_Change Percent_Change    Market_Cap         Country  IPO_Year  \
# Ticker
# A           1.3200          0.90%  4.254173e+10   United States    1999.0
# AA         -0.0100        -0.025%  1.014502e+10   United States    2016.0
# AACT        0.0199         0.184%  0.000000e+00             NaN    2023.0
# AAM         0.0000          0.00%  0.000000e+00             NaN    2024.0
# AAN         0.0200         0.199%  3.086634e+08   United States    2020.0
# ...            ...            ...           ...             ...       ...
# ZURA        0.1000         2.519%  2.735328e+08  Cayman Islands       NaN
# ZVRA       -0.3900        -5.335%  3.641151e+08   United States       NaN
# ZVSA        0.0600         2.609%  2.428903e+06   United States    2022.0
# ZYME       -0.0500        -0.401%  8.824086e+08   United States       NaN
# ZYXI       -0.1600        -1.937%  2.571144e+08   United States       NaN
#
#          Volume                  Sector  \
# Ticker
# A       2212993             Industrials
# AA      5629158             Industrials
# AACT       2476                 Finance
# AAM      537105                     NaN
# AAN     1425538  Consumer Discretionary
# ...         ...                     ...
# ZURA     393346             Health Care
# ZVRA    1660748             Health Care
# ZVSA      53919             Health Care
# ZYME     283590             Health Care
# ZYXI     105359             Health Care
#
#                                                  Industry Exchange
# Ticker
# A        Biotechnology: Laboratory Analytical Instruments     NYSE
# AA                                               Aluminum     NYSE
# AACT                                         Blank Checks     NYSE
# AAM                                                   NaN     NYSE
# AAN                       Diversified Commercial Services     NYSE
# ...                                                   ...      ...
# ZURA    Biotechnology: Biological Products (No Diagnos...   NASDAQ
# ZVRA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZVSA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYME           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYXI    Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6689 rows x 11 columns]

# %%
company_data.to_csv('company_data_cleaned_'+date+'.csv')

# %%
company_data.index
# Out:
# Index(['A', 'AA', 'AACT', 'AAM', 'AAN', 'AAP', 'AAT', 'AB', 'ABBV', 'ABCB',
#        ...
#        'ZPTA', 'ZPTAW', 'ZS', 'ZTEK', 'ZUMZ', 'ZURA', 'ZVRA', 'ZVSA', 'ZYME',
#        'ZYXI'],
#       dtype='object', name='Ticker', length=6689)

# %%
raise SystemExit("Stop right there!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# C:\Users\matth\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from IPython.display import clear_output
from tqdm import tqdm

# %%
# getting company data from yfinance.
# this does three things: 
# -gives us updated market cap data
# -will throw errors (which are caught) if the company doesn't have data in yfinance
# tells us if its an 'equity' or something in the 'Quote_Type' columns

# %%
company_data_yf = pd.DataFrame({
    'Market_Cap':[],
    'Quote_Type':[],
    'Shares':[],
    'Currency':[],
    'Exchange':[],
    'Time_Zone':[]
})
company_data_yf.index.name = 'Ticker'

display(company_data_yf)

# list of tickers from nasdaq download data
tickers = company_data.index

# progress bar/for loop
for ticker in tqdm(tickers, desc="Fetching company data"):
    print(f'Getting {ticker}')
    
    try:
        company_data_yf.loc[ticker, 'Market_Cap'] = yf.Ticker(ticker).fast_info['marketCap']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Quote_Type'] = yf.Ticker(ticker).fast_info['quoteType']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Shares'] = yf.Ticker(ticker).fast_info['shares']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Currency'] = yf.Ticker(ticker).fast_info['currency']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Exchange'] = yf.Ticker(ticker).fast_info['exchange']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Time_Zone'] = yf.Ticker(ticker).fast_info['timezone']
    except:
        pass

    clear_output()

display(company_data_yf, clear=True)

# %%
company_data_yf.to_csv('company_data_yf_.csv')

# %% [markdown]
# ### START HERE

# %%
company_data_yf = pd.read_csv('company_data_yf_'+date+'.csv')

# %%
print(company_data_yf['Quote_Type'].value_counts())
print()
print(company_data_yf['Currency'].value_counts())
print()
print(company_data_yf['Exchange'].value_counts())
# Out:
# Quote_Type
# EQUITY        6317
# ECNQUOTE         4
# ETF              4
# MUTUALFUND       3
# Name: count, dtype: int64
#
# Currency
# USD    6317
# Name: count, dtype: int64
#
# Exchange
# NYQ    2409
# NCM    1592
# NMS    1534
# NGM     785
# PNK       3
# YHD       3
# PCX       1
# ASE       1
# Name: count, dtype: int64

# %%
company_data_clean = pd.read_csv('company_data_cleaned_'+date+'.csv',index_col=0)
company_data_clean
# Out:
#                                                      Name Last_Sale  \
# Ticker
# A                  Agilent Technologies Inc. Common Stock   $148.06
# AA                        Alcoa Corporation Common Stock     $39.27
# AACT    Ares Acquisition Corporation II Class A Ordina...  $10.8299
# AAM     AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# AAN            Aarons Holdings Company Inc. Common Stock     $10.05
# ...                                                   ...       ...
# ZURA             Zura Bio Limited Class A Ordinary Shares     $4.07
# ZVRA                 Zevra Therapeutics Inc. Common Stock     $6.92
# ZVSA               ZyVersa Therapeutics Inc. Common Stock     $2.36
# ZYME                          Zymeworks Inc. Common Stock    $12.42
# ZYXI                              Zynex Inc. Common Stock     $8.10
#
#         Net_Change Percent_Change    Market_Cap         Country  IPO_Year  \
# Ticker
# A           1.3200          0.90%  4.254173e+10   United States    1999.0
# AA         -0.0100        -0.025%  1.014502e+10   United States    2016.0
# AACT        0.0199         0.184%  0.000000e+00             NaN    2023.0
# AAM         0.0000          0.00%  0.000000e+00             NaN    2024.0
# AAN         0.0200         0.199%  3.086634e+08   United States    2020.0
# ...            ...            ...           ...             ...       ...
# ZURA        0.1000         2.519%  2.735328e+08  Cayman Islands       NaN
# ZVRA       -0.3900        -5.335%  3.641151e+08   United States       NaN
# ZVSA        0.0600         2.609%  2.428903e+06   United States    2022.0
# ZYME       -0.0500        -0.401%  8.824086e+08   United States       NaN
# ZYXI       -0.1600        -1.937%  2.571144e+08   United States       NaN
#
#          Volume                  Sector  \
# Ticker
# A       2212993             Industrials
# AA      5629158             Industrials
# AACT       2476                 Finance
# AAM      537105                     NaN
# AAN     1425538  Consumer Discretionary
# ...         ...                     ...
# ZURA     393346             Health Care
# ZVRA    1660748             Health Care
# ZVSA      53919             Health Care
# ZYME     283590             Health Care
# ZYXI     105359             Health Care
#
#                                                  Industry Exchange
# Ticker
# A        Biotechnology: Laboratory Analytical Instruments     NYSE
# AA                                               Aluminum     NYSE
# AACT                                         Blank Checks     NYSE
# AAM                                                   NaN     NYSE
# AAN                       Diversified Commercial Services     NYSE
# ...                                                   ...      ...
# ZURA    Biotechnology: Biological Products (No Diagnos...   NASDAQ
# ZVRA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZVSA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYME           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYXI    Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6689 rows x 11 columns]

# %%
company_data_yf = pd.read_csv('company_data_yf_'+date+'.csv',index_col=0)
company_data_yf
# Out:
#           Market_Cap Quote_Type       Shares Currency Exchange  \
# Ticker
# A       4.254178e+10     EQUITY  287328000.0      USD      NYQ
# AA      1.014760e+10     EQUITY  258406000.0      USD      NYQ
# AACT    6.768750e+08     EQUITY   62500000.0      USD      NYQ
# AAM     4.401797e+08     EQUITY   43974000.0      USD      NYQ
# AAN     3.170855e+08     EQUITY   31550800.0      USD      NYQ
# ...              ...        ...          ...      ...      ...
# ZURA    2.595610e+08     EQUITY   63774200.0      USD      NCM
# ZVRA    3.641152e+08     EQUITY   52617800.0      USD      NMS
# ZVSA    2.535112e+06     EQUITY    1074200.0      USD      NCM
# ZYME    8.824087e+08     EQUITY   71047400.0      USD      NMS
# ZYXI    2.618754e+08     EQUITY   32330300.0      USD      NMS
#
#                Time_Zone
# Ticker
# A       America/New_York
# AA      America/New_York
# AACT    America/New_York
# AAM     America/New_York
# AAN     America/New_York
# ...                  ...
# ZURA    America/New_York
# ZVRA    America/New_York
# ZVSA    America/New_York
# ZYME    America/New_York
# ZYXI    America/New_York
#
# [6328 rows x 6 columns]

# %%
company_data_clean_filtered = company_data_clean.loc[company_data_yf.index,:]
company_data_clean_filtered.shape
# Out:
# (6666, 11)

# %%
company_data_clean_filtered.index.unique()
# Out:
# Index(['A', 'AA', 'AACT', 'AAM', 'AAN', 'AAP', 'AAT', 'AB', 'ABBV', 'ABCB',
#        ...
#        'ZPTA', 'ZPTAW', 'ZS', 'ZTEK', 'ZUMZ', 'ZURA', 'ZVRA', 'ZVSA', 'ZYME',
#        'ZYXI'],
#       dtype='object', name='Ticker', length=6328)

# %%
tickersAll = pd.DataFrame({'tickers':company_data_clean_filtered.index.unique()
})

# %%
tickersAll.to_csv('allTickers.csv')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
duplicates = company_data_clean_filtered.loc[
    company_data_clean_filtered.index[company_data_clean_filtered.index.duplicated()],:]
duplicates_to_trash_list = list(duplicates.index)
print(len(duplicates_to_trash_list))
print(len(set(duplicates_to_trash_list)))
# Out:
# 1560
# 162

# %%
duplicates_to_keep = duplicates[(duplicates['IPO_Year'].notna())].drop_duplicates().sort_index() #duplicates[duplicates['IPO_Year'].notna().drop_duplicates().sort_index()]
duplicates_to_keep.shape
# Out:
# (80, 11)

# %%
company_data_clean_filtered_unique = company_data_clean_filtered.loc[[(x not in duplicates_to_trash_list) for x in company_data_clean_filtered.index] ,:]
company_data_clean_filtered_unique.shape
# Out:
# (6166, 11)

# %%
company_data_clean_filtered_unique = pd.concat([company_data_clean_filtered_unique,duplicates_to_keep],axis=0)
company_data_clean_filtered_unique.shape
# Out:
# (6246, 11)

# %%
oi_smol = set(duplicates[duplicates['IPO_Year'].notna()].index.unique())

# %%
oi_beeg = set(duplicates[(duplicates['IPO_Year'].notna())].drop_duplicates().sort_index().index)

# %%
len(oi_beeg)

# %%
pd.reset_option('all')

# %%
oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index()

# %%
company_data_clean_filtered.loc[
    company_data_clean_filtered.index[
        company_data_clean_filtered.index.duplicated()
        ],:]#.value_counts('Ticker')

# %%
oi = company_data_clean_filtered.loc[
    company_data_clean_filtered.index[
        company_data_clean_filtered.index.duplicated()
        ],:]

# %%
pd.set_option('display.max_rows',100)
(oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index())

# %%
len(oi_actual_beeg)

# %%
len(oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index().index)

# %%
oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index().index

# %%
oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index()[
    oi[(oi['IPO_Year'].notna())].drop_duplicates().sort_index().index.duplicated()
]

# %%
oi.loc[:,:].drop_duplicates()

# %%
oi.index.unique()

# %%
oi.iat[1,6]

# %%
yf.Ticker('PSA').fast_info['marketCap']
