# %%
import pandas as pd
import yfinance as yf
import numpy as np
import re
# files from https://www.nasdaq.com/market-activity/stocks/screener
# files gotten on 2024-09-29

date = '2024-09-29'

# %%
nasdaq = pd.read_csv('nasdaq_screener_nasdaq_'+date+'.csv')
nyse = pd.read_csv('nasdaq_screener_nyse_'+date+'.csv')
nyse['Exchange'] = 'NYSE'
nasdaq['Exchange'] = 'NASDAQ'
company_data = pd.concat([nyse,nasdaq],axis=0)
del(nyse,nasdaq)
company_data = company_data.rename(columns={'Symbol':'Ticker'})
# company_data.index=company_data['Symbol']
# nyse_and_nasdaq.drop(columns='Symbol',inplace=True)
# nyse_and_nasdaq.index.name='Ticker'
company_data

# %%
odd = list({x for x in company_data['Ticker'] if (not (str(x).isalnum()))})
odd_with_arrow = list({x for x in company_data['Ticker'] if  (str(x).__contains__('^')) })
odd_no_arrow = list({x for x in company_data['Ticker'] if (not (str(x).isalnum()) and  not (str(x).__contains__('^')) )})
company_data

# %%
# there seem to be a few types of odd tickers here, ones formatted like xxx^x and ones with xx/x in it and/or whitespace.
# it seems like all the rows with a ticker of the format "xxx^x" are something like prefered stock or some other nonsense
# the ones with / need to have the / swapped with - for the yfinance library to get their data
# and the whitespace needs to be removed. This does that
odd_cleaned = {x: re.split('[^a-zA-Z0-9]+', x)[0] for x in odd_with_arrow}
odd_cleaned.update({x: x.strip().replace('/', '-') for x in odd_no_arrow})
# and this updates the names in the dataframe
company_data['Ticker'] = company_data['Ticker'].replace(odd_cleaned)
company_data = company_data.reset_index()
company_data = company_data.drop(columns='index')
company_data

# %%
# 
company_data.index = company_data['Ticker']
company_data = company_data.drop(columns=['Ticker'])
# clean up invalid data
company_data = company_data[company_data.index.notna()]

# %%
company_data

# %%
# Rename columns to be more code friendly (underscores)
rename_dict = {
    'Name': 'Name',
    'Last Sale': 'Last_Sale',
    'Net Change': 'Net_Change',
    '% Change': 'Percent_Change',
    'Market Cap': 'Market_Cap',
    'Country': 'Country',
    'IPO Year': 'IPO_Year',
    'Volume': 'Volume',
    'Sector': 'Sector',
    'Industry': 'Industry',
    'Exchange': 'Exchange'
}
company_data = company_data.rename(columns=rename_dict)
company_data

# %%
company_data.to_csv('company_data_cleaned_'+date+'.csv')

# %%
company_data.index

# %%
raise SystemExit("Stop right there!")

# %% [markdown]
# ### Only run the code below if it is CURRENTLY the last day you have stock price data for AFTER MARKET CLOSE

# %%
from IPython.display import clear_output
from tqdm import tqdm

# %%
# getting company data from yfinance.
# this does three things: 
# -gives us updated market cap data
# -will throw errors (which are caught) if the company doesn't have data in yfinance
# tells us if its an 'equity' or something in the 'Quote_Type' columns

# %%
company_data_yf = pd.DataFrame({
    'Market_Cap':[],
    'Quote_Type':[],
    'Shares':[],
    'Currency':[],
    'Exchange':[],
    'Time_Zone':[]
})
company_data_yf.index.name = 'Ticker'

display(company_data_yf)

# list of tickers from nasdaq download data
tickers = company_data.index

# progress bar/for loop
for ticker in tqdm(tickers, desc="Fetching company data"):
    print(f'Getting {ticker}')
    
    try:
        company_data_yf.loc[ticker, 'Market_Cap'] = yf.Ticker(ticker).fast_info['marketCap']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Quote_Type'] = yf.Ticker(ticker).fast_info['quoteType']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Shares'] = yf.Ticker(ticker).fast_info['shares']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Currency'] = yf.Ticker(ticker).fast_info['currency']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Exchange'] = yf.Ticker(ticker).fast_info['exchange']
    except:
        pass
    try:
        company_data_yf.loc[ticker, 'Time_Zone'] = yf.Ticker(ticker).fast_info['timezone']
    except:
        pass

    clear_output()

display(company_data_yf, clear=True)

# %%
company_data_yf.to_csv('company_data_yf_.csv')

# %% [markdown]
# ### START HERE

# %%
company_data_yf = pd.read_csv('company_data_yf_'+date+'.csv',index_col=0)
company_data_yf
# Out:
#           Market_Cap Quote_Type       Shares Currency Exchange  \
# Ticker
# A       4.254178e+10     EQUITY  287328000.0      USD      NYQ
# AA      1.014760e+10     EQUITY  258406000.0      USD      NYQ
# AACT    6.768750e+08     EQUITY   62500000.0      USD      NYQ
# AAM     4.401797e+08     EQUITY   43974000.0      USD      NYQ
# AAN     3.170855e+08     EQUITY   31550800.0      USD      NYQ
# ...              ...        ...          ...      ...      ...
# ZURA    2.595610e+08     EQUITY   63774200.0      USD      NCM
# ZVRA    3.641152e+08     EQUITY   52617800.0      USD      NMS
# ZVSA    2.535112e+06     EQUITY    1074200.0      USD      NCM
# ZYME    8.824087e+08     EQUITY   71047400.0      USD      NMS
# ZYXI    2.618754e+08     EQUITY   32330300.0      USD      NMS
#
#                Time_Zone
# Ticker
# A       America/New_York
# AA      America/New_York
# AACT    America/New_York
# AAM     America/New_York
# AAN     America/New_York
# ...                  ...
# ZURA    America/New_York
# ZVRA    America/New_York
# ZVSA    America/New_York
# ZYME    America/New_York
# ZYXI    America/New_York
#
# [6328 rows x 6 columns]

# %%
print(company_data_yf['Quote_Type'].value_counts())
print()
print(company_data_yf['Currency'].value_counts())
print()
print(company_data_yf['Exchange'].value_counts())
# Out:
# Quote_Type
# EQUITY        6317
# ECNQUOTE         4
# ETF              4
# MUTUALFUND       3
# Name: count, dtype: int64
#
# Currency
# USD    6317
# Name: count, dtype: int64
#
# Exchange
# NYQ    2409
# NCM    1592
# NMS    1534
# NGM     785
# PNK       3
# YHD       3
# PCX       1
# ASE       1
# Name: count, dtype: int64

# %%
company_data_clean = pd.read_csv('company_data_cleaned_'+date+'.csv',index_col=0)
company_data_clean
# Out:
#                                                      Name Last_Sale  \
# Ticker
# A                  Agilent Technologies Inc. Common Stock   $148.06
# AA                        Alcoa Corporation Common Stock     $39.27
# AACT    Ares Acquisition Corporation II Class A Ordina...  $10.8299
# AAM     AA Mission Acquisition Corp. Class A Ordinary ...    $10.01
# AAN            Aarons Holdings Company Inc. Common Stock     $10.05
# ...                                                   ...       ...
# ZURA             Zura Bio Limited Class A Ordinary Shares     $4.07
# ZVRA                 Zevra Therapeutics Inc. Common Stock     $6.92
# ZVSA               ZyVersa Therapeutics Inc. Common Stock     $2.36
# ZYME                          Zymeworks Inc. Common Stock    $12.42
# ZYXI                              Zynex Inc. Common Stock     $8.10
#
#         Net_Change Percent_Change    Market_Cap         Country  IPO_Year  \
# Ticker
# A           1.3200          0.90%  4.254173e+10   United States    1999.0
# AA         -0.0100        -0.025%  1.014502e+10   United States    2016.0
# AACT        0.0199         0.184%  0.000000e+00             NaN    2023.0
# AAM         0.0000          0.00%  0.000000e+00             NaN    2024.0
# AAN         0.0200         0.199%  3.086634e+08   United States    2020.0
# ...            ...            ...           ...             ...       ...
# ZURA        0.1000         2.519%  2.735328e+08  Cayman Islands       NaN
# ZVRA       -0.3900        -5.335%  3.641151e+08   United States       NaN
# ZVSA        0.0600         2.609%  2.428903e+06   United States    2022.0
# ZYME       -0.0500        -0.401%  8.824086e+08   United States       NaN
# ZYXI       -0.1600        -1.937%  2.571144e+08   United States       NaN
#
#          Volume                  Sector  \
# Ticker
# A       2212993             Industrials
# AA      5629158             Industrials
# AACT       2476                 Finance
# AAM      537105                     NaN
# AAN     1425538  Consumer Discretionary
# ...         ...                     ...
# ZURA     393346             Health Care
# ZVRA    1660748             Health Care
# ZVSA      53919             Health Care
# ZYME     283590             Health Care
# ZYXI     105359             Health Care
#
#                                                  Industry Exchange
# Ticker
# A        Biotechnology: Laboratory Analytical Instruments     NYSE
# AA                                               Aluminum     NYSE
# AACT                                         Blank Checks     NYSE
# AAM                                                   NaN     NYSE
# AAN                       Diversified Commercial Services     NYSE
# ...                                                   ...      ...
# ZURA    Biotechnology: Biological Products (No Diagnos...   NASDAQ
# ZVRA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZVSA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYME           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYXI    Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6689 rows x 11 columns]

# %%
# filters out companies that yahoo finance doesn't have historical data for
company_data_clean_filtered = company_data_clean.loc[company_data_yf.index,:]
company_data_clean_filtered.shape
# Out:
# (6666, 11)

# %%
unique_ticker_list = list(set(company_data_clean_filtered.index))
print(unique_ticker_list)
print(len(unique_ticker_list))
# Out:
# ['VRNS', 'PMTS', 'JFBRW', 'ROG', 'STKH', 'SRZNW', 'BNTX', 'OCS', 'BDC', 'JVA', 'SHMDW', 'EXTO', 'CHRS', 'CRL', 'IBOC', 'PSTV', 'KPTI', 'VMEO', 'INNV', 'RMT', 'AS', 'LGVN', 'MFI', 'UTMD', 'SIGI', 'NVEC', 'VOR', 'TCBI', 'BFZ', 'NMRK', 'CNTB', 'TT', 'MITAW', 'SBSW', 'KDP', 'PIII', 'COOT', 'NXL', 'EL', 'HBANM', 'COCO', 'XWEL', 'OCX', 'SGA', 'MNDR', 'LFT', 'GBIO', 'GOGL', 'VSH', 'API', 'FMX', 'BCSA', 'KTOS', 'GECCI', 'CHRD', 'ENG', 'NMR', 'RNR', 'CABO', 'ANTX', 'QURE', 'HOTH', 'GNFT', 'BBUC', 'TGT', 'KNSL', 'ASRT', 'TRIB', 'ARM', 'WFG', 'CODI', 'QIPT', 'LECO', 'GYRO', 'FRST', 'ZJYL', 'TSLA', 'DIOD', 'AMRC', 'SHCO', 'BFRI', 'GDEV', 'CELZ', 'DATS', 'VIRT', 'EME', 'STCN', 'FEMY', 'BDSX', 'CENT', 'AZEK', 'MBINM', 'ALGT', 'ROAD', 'OGE', 'FSS', 'UPST', 'LEGN', 'CCNE', 'MHLD', 'IBTX', 'CKPT', 'SXTC', 'CARM', 'SMXT', 'KZR', 'DSGN', 'HFFG', 'HLF', 'KBH', 'AVXL', 'OABIW', 'URI', 'HLLY', 'LIXT', 'PTIXW', 'ARES', 'UFCS', 'CMBM', 'SEDA', 'DRTS', 'SMBC', 'RCS', 'ASGI', 'SFBC', 'AGNCM', 'USFD', 'RENE', 'CUB', 'JNJ', 'IPI', 'MESA', 'SKLZ', 'SLGN', 'BSM', 'ETV', 'FLGC', 'IXAQ', 'TSN', 'KPLT', 'BEAT', 'CVCO', 'FIACW', 'LX', 'APG', 'ENO', 'XPER', 'ANIK', 'BBVA', 'CLDX', 'FRSX', 'RGC', 'AMWD', 'RCMT', 'QSI', 'AUUDW', 'WHFCL', 'NRGV', 'PUMP', 'GRND', 'AMLX', 'FCCO', 'BLEU', 'CFB', 'UNIT', 'UI', 'AL', 'RYI', 'MRUS', 'RJF', 'GM', 'NEUE', 'PDYN', 'TLSI', 'IBM', 'OII', 'PANL', 'HCVIU', 'OXSQ', 'DTW', 'PFTAU', 'CTRA', 'SMHI', 'CMCO', 'SELF', 'NAUT', 'COGT', 'RM', 'ALVO', 'CSWI', 'DBRG', 'LE', 'CTXR', 'DFIN', 'COMP', 'ETHA', 'AMCR', 'HTZWW', 'SFB', 'KNF', 'COST', 'PLYM', 'NOAH', 'SKE', 'KFS', 'CGBS', 'BCTXW', 'OXM', 'GSBC', 'OSUR', 'ATO', 'DNA', 'NPABW', 'EHAB', 'FPI', 'AWF', 'ICLR', 'OGN', 'CTNM', 'XPOF', 'FOXA', 'JBI', 'CCS', 'NFJ', 'PTPI', 'MSGE', 'NXG', 'CSGP', 'SRCE', 'FSLR', 'NXGLW', 'TDS', 'ZEPP', 'OGS', 'FAASW', 'POLEU', 'LMB', 'TENX', 'NPV', 'BUI', 'DM', 'IMTE', 'WSC', 'DLTR', 'ALLK', 'KLG', 'FLYW', 'KVAC', 'AREB', 'RELI', 'DLR', 'RVMD', 'BWBBP', 'EXLS', 'ENLT', 'GDTC', 'CHEF', 'MQT', 'SCOR', 'FTEK', 'LKFN', 'UNFI', 'HLNE', 'NUTX', 'EPRX', 'BNJ', 'DHX', 'OVLY', 'MATX', 'IXAQW', 'JHI', 'IREN', 'SCSC', 'XOM', 'GRPN', 'IART', 'TRAK', 'HOUR', 'OXLCN', 'SMSI', 'LNC', 'SNEX', 'KRC', 'EFSC', 'SNES', 'EVTC', 'IR', 'HNST', 'SEVN', 'SBS', 'CBZ', 'NUVL', 'QVCD', 'AFJK', 'EXK', 'RFIL', 'BARK', 'BRBR', 'GSMGW', 'ITW', 'TR', 'SLNHP', 'XOS', 'RNAZ', 'ADNT', 'MNTK', 'CM', 'GJO', 'IPDN', 'VIR', 'GRYP', 'DXPE', 'BRNS', 'BLIN', 'HBT', 'RENB', 'STER', 'MSA', 'CASS', 'PYXS', 'ARCB', 'NVT', 'XELAP', 'KTH', 'OSW', 'TSE', 'RMCOW', 'SATLW', 'VOC', 'AQMS', 'DRIO', 'SPHR', 'SHLT', 'ABL', 'VRSN', 'ALSA', 'CVLG', 'FTAIO', 'SJM', 'ITT', 'TXNM', 'SAH', 'ABUS', 'IVP', 'CCSI', 'SWIN', 'ARDX', 'NAPA', 'RVTY', 'LNTH', 'DTSQ', 'SENEA', 'ANTE', 'HPQ', 'NRP', 'MDB', 'DOV', 'SAM', 'EJH', 'LNN', 'AVO', 'SCWX', 'ELEV', 'TPGXL', 'AESI', 'DOCS', 'ABLLW', 'ASTI', 'CLNN', 'GWAV', 'MGEE', 'FOSLL', 'ISPOW', 'BBDC', 'EFR', 'NCDL', 'NATR', 'VRN', 'VLGEA', 'DRD', 'LTRN', 'OPBK', 'FRAF', 'IGI', 'ARDT', 'MBC', 'AVGR', 'EBMT', 'JFIN', 'EMO', 'LTH', 'VALU', 'GDSTR', 'NVST', 'SSD', 'GNLX', 'CGNT', 'PCTY', 'OP', 'ADUS', 'NLSP', 'BERY', 'GECCH', 'FBIN', 'CNFRZ', 'HTGC', 'INHD', 'NTBL', 'PRPO', 'DOYU', 'RCKTW', 'NU', 'VEV', 'SPRC', 'FGFPP', 'AFL', 'ONDS', 'WLDS', 'IPXX', 'STRT', 'IRIX', 'PECO', 'FNGR', 'UMH', 'EVGR', 'AGNCO', 'FGN', 'CRWS', 'GNRC', 'AITRR', 'OWL', 'CFG', 'CEP', 'MTZ', 'PAYS', 'BOXL', 'ALGS', 'QRTEP', 'GROV', 'SMWB', 'BLFS', 'IGIC', 'TRMD', 'VCIG', 'NNDM', 'MTEM', 'SOHOO', 'RVT', 'SKM', 'SNDL', 'RBC', 'CMSC', 'XBPEW', 'RNP', 'JAGX', 'PWP', 'LION', 'DARE', 'PTLO', 'FOXF', 'EQNR', 'SYRE', 'MPC', 'AUPH', 'GLDD', 'EBC', 'KORE', 'SPRB', 'AQNB', 'NIU', 'POCI', 'MOD', 'NRUC', 'FIVN', 'BWMN', 'ADX', 'FUND', 'NVG', 'RNXT', 'CB', 'DTF', 'NBXG', 'PALT', 'VCEL', 'NMHIW', 'ESLT', 'GOOD', 'SQFTP', 'CDLR', 'IFN', 'CREV', 'MRAM', 'TITN', 'NDAQ', 'PROP', 'UNH', 'BEPJ', 'FPF', 'FREY', 'GCMG', 'TECX', 'SPRU', 'AXGN', 'GHY', 'BLUE', 'SXTP', 'CTRM', 'TNET', 'SPCE', 'DSL', 'ESGRP', 'SGHC', 'REGN', 'AVAV', 'NXP', ...
# 6328

# %%
# Function to keep rows with the most non-NaN values
def keep_most_non_na(group):
    # Count non-NaN values in each row
    non_na_count = group.notna().sum(axis=1)
    # Filter rows with the maximum count of non-NaN values
    return group[non_na_count == non_na_count.max()]

# %%
company_data_clean_filtered_unique = pd.DataFrame()
for ticker in unique_ticker_list:
    company_data_clean_filtered_unique = pd.concat([company_data_clean_filtered_unique,
                                                   keep_most_non_na(company_data_clean_filtered.loc[[ticker],:])],
                                                   axis=0)
company_data_clean_filtered_unique = company_data_clean_filtered_unique.sort_index()

# %%
# tickers that appear more than once
repeated_index = company_data_clean_filtered_unique.index[company_data_clean_filtered_unique.index.duplicated(keep=False)]

# subset of the DataFrame with only the repeated index values
subset_df = company_data_clean_filtered_unique.loc[repeated_index].drop_duplicates()

# gets list of duplicate tickers
duplicate_tickers = list(set(subset_df.index))

# removes them
company_data_clean_filtered_unique = company_data_clean_filtered_unique.drop(index=duplicate_tickers,errors='ignore')
display(company_data_clean_filtered_unique)
# Out:
#                                                      Name Last_Sale  \
# Ticker
# A                  Agilent Technologies Inc. Common Stock   $148.06
# AA                        Alcoa Corporation Common Stock     $39.27
# AACG     ATA Creativity Global American Depositary Shares   $0.7302
# AACT    Ares Acquisition Corporation II Class A Ordina...  $10.8299
# AADI                    Aadi Bioscience Inc. Common Stock     $1.93
# ...                                                   ...       ...
# ZVRA                 Zevra Therapeutics Inc. Common Stock     $6.92
# ZVSA               ZyVersa Therapeutics Inc. Common Stock     $2.36
# ZWS     Zurn Elkay Water Solutions Corporation Common ...    $35.66
# ZYME                          Zymeworks Inc. Common Stock    $12.42
# ZYXI                              Zynex Inc. Common Stock     $8.10
#
#         Net_Change Percent_Change    Market_Cap        Country  IPO_Year  \
# Ticker
# A           1.3200          0.90%  4.254173e+10  United States    1999.0
# AA         -0.0100        -0.025%  1.014502e+10  United States    2016.0
# AACG        0.0078          1.08%  2.336650e+07          China    2008.0
# AACT        0.0199         0.184%  0.000000e+00            NaN    2023.0
# AADI        0.0200         1.047%  4.750663e+07  United States       NaN
# ...            ...            ...           ...            ...       ...
# ZVRA       -0.3900        -5.335%  3.641151e+08  United States       NaN
# ZVSA        0.0600         2.609%  2.428903e+06  United States    2022.0
# ZWS         0.5700         1.624%  6.095310e+09  United States    2012.0
# ZYME       -0.0500        -0.401%  8.824086e+08  United States       NaN
# ZYXI       -0.1600        -1.937%  2.571144e+08  United States       NaN
#
#          Volume       Sector  \
# Ticker
# A       2212993  Industrials
# AA      5629158  Industrials
# AACG      26100  Real Estate
# AACT       2476      Finance
# AADI      81024  Health Care
# ...         ...          ...
# ZVRA    1660748  Health Care
# ZVSA      53919  Health Care
# ZWS     1408735  Industrials
# ZYME     283590  Health Care
# ZYXI     105359  Health Care
#
#                                                  Industry Exchange
# Ticker
# A        Biotechnology: Laboratory Analytical Instruments     NYSE
# AA                                               Aluminum     NYSE
# AACG                              Other Consumer Services   NASDAQ
# AACT                                         Blank Checks     NYSE
# AADI           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ...                                                   ...      ...
# ZVRA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZVSA           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZWS                       Industrial Machinery/Components     NYSE
# ZYME           Biotechnology: Pharmaceutical Preparations   NASDAQ
# ZYXI    Biotechnology: Electromedical & Electrotherape...   NASDAQ
#
# [6322 rows x 11 columns]

# %%
company_data_clean_filtered_unique.to_csv('company_data_cleaned_2024-09-29.csv')
